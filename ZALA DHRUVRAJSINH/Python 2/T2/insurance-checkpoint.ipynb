# %%
import pandas as pd
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
df=pd.read_csv("insurance.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   object
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1334 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 73.3+ KB

# %%
df=df.drop_duplicates()
df=df.dropna()
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female    27.9         0    yes  southwest  16884.92400
# 1      18    male   33.77         1     no  southeast   1725.55230
# 2      28    male      33         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male   28.88         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male   30.97         3     no  northwest  10600.54830
# 1334   18  female   31.92         0     no  northeast   2205.98080
# 1335   18  female   36.85         0     no  southeast   1629.83350
# 1336   21  female    25.8         0     no  southwest   2007.94500
# 1337   61  female   29.07         0    yes  northwest  29141.36030
#
# [1333 rows x 7 columns]

# %%
df=df.loc[df['bmi']!='-']
df['bmi']=df['bmi'].astype('float64')
df['bmi']
# Out:
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1332, dtype: float64

# %%
fig,ax=plt.subplots()
ax.boxplot([df['bmi']])
plt.show()

# %%
def function(df,col):
    d1=df[col].quantile(0.25)
    d2=df[col].quantile(0.75)
    iqr=d2-d1
    upper_limit=d1+1.5*iqr
    lower_limit=d2-1.5*iqr
    df=df.loc[df[col]<=upper_limit]
    df=df.loc[df[col]>=lower_limit]
    return df
df=function(df,'bmi')
fig,ax=plt.subplots()
ax.boxplot([df['bmi']])
plt.show()

# %%
df=pd.get_dummies(df,drop_first=True)
df
# Out:
#       age    bmi  children     charges  gender_male  smoker_yes  \
# 0      19  27.90         0  16884.9240            0           1
# 1      18  33.77         1   1725.5523            1           0
# 2      28  33.00         3   4449.4620            1           0
# 4      32  28.88         0   3866.8552            1           0
# 5      31  25.74         0   3756.6216            0           0
# ...   ...    ...       ...         ...          ...         ...
# 1327   51  30.03         1   9377.9047            1           0
# 1333   50  30.97         3  10600.5483            1           0
# 1334   18  31.92         0   2205.9808            0           0
# 1336   21  25.80         0   2007.9450            0           0
# 1337   61  29.07         0  29141.3603            0           1
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# 1                    0                 1                 0
# 2                    0                 1                 0
# 4                    1                 0                 0
# 5                    0                 1                 0
# ...                ...               ...               ...
# 1327                 0                 1                 0
# 1333                 1                 0                 0
# 1334                 0                 0                 0
# 1336                 0                 0                 1
# 1337                 1                 0                 0
#
# [860 rows x 9 columns]

# %%
x=df.drop('charges',axis=1)
y=df['charges']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 3768.220671816121
# 31294839.123021208
# 0.7672641879569402
