# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
df=pd.read_csv("Marksheet.csv")
df=df.loc[(df['TEST-3 MARKS']!='AB')&(df['TEST-4 MARKS']!='AB')]
df['TEST-3 MARKS']=df['TEST-3 MARKS'].astype('float64')
df['TEST-4 MARKS']=df['TEST-4 MARKS'].astype('float64')
df.info()
df['TOTAL']=df['TEST-1 MARKS']+df['TEST-2 MARKS']+df['TEST-3 MARKS']+df['TEST-4 MARKS']
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299 entries, 0 to 301
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sr no         299 non-null    int64
#  1   Branch        299 non-null    object
#  2   Enrolment No  299 non-null    float64
#  3   Name          299 non-null    object
#  4   Roll No       299 non-null    int64
#  5   Div           299 non-null    object
#  6   Mentor Name   298 non-null    object
#  7   TEST-1 MARKS  299 non-null    float64
#  8   TEST-2 MARKS  299 non-null    float64
#  9   TEST-3 MARKS  299 non-null    float64
#  10  TEST-4 MARKS  299 non-null    float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 28.0+ KB
#      sr no Branch  Enrolment No                            Name  Roll No Div  \
# 0        1     CE  2.200220e+13  KATHIRIYA VRAJKUMAR ASHVINBHAI      110  A4
# 1        2     CE  2.300220e+13       AGRAVAT SAHIL RAJARAMBHAI      101  A3
# ...

# %%
l=list()
for i in df['TOTAL']:
    grade=""
    if(i>=85):
        grade='A'
    elif(i>=75 and i<=84.99):
        grade='B'
    elif(i>=65 and i<=74.99):
        grade='C'
    elif(i>=50 and i<=64.99):
        grade='D'
    elif(i>=35 and i<=49.99):
        grade='E'
    else:
        grade='B'
    l.append(grade)
df['GRADES']=l
df
# Out:
#      sr no Branch  Enrolment No                            Name  Roll No Div  \
# 0        1     CE  2.200220e+13  KATHIRIYA VRAJKUMAR ASHVINBHAI      110  A4
# 1        2     CE  2.300220e+13       AGRAVAT SAHIL RAJARAMBHAI      101  A3
# 2        3     CE  2.300220e+13      BALAR RAGHUBHAI SURESHBHAI      162  A5
# 3        4     CE  2.300220e+13   BALESANA HASSANBHAI YUNUSBHAI      122  A4
# 4        5     CE  2.300220e+13      BAMBHROLIYA HIT NARESHBHAI       87  A3
# ..     ...    ...           ...                             ...      ...  ..
# 297    299   AIDS  2.400220e+13                 SHELADIYA HARSH       41  A9
# 298    300   AIDS  2.400220e+13                     HET THESIYA       43  A9
# 299    301   AIDS  2.400220e+13       VAIDYA YOGANSHU VIRENBHAI       30  A9
# 300    302   AIDS  2.400220e+13           VIRJA DEEP BHARATBHAI       35  A9
# 301    303   AIDS  2.400220e+13               VORA MAHAMMADKAIF       49  A9
#
# ...

# %%
x=df[['TEST-1 MARKS']]
y=df['TOTAL']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
y_pred
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 132.74864441803135
# 0.5584500691644695

# %%
sns.regplot(x=x,y=y)
plt.show()

# %%
rs=range(0,51)
r2_scores=[]
for i in rs:
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    r2_scores.append(r2_score(y_test,y_pred))
print(max(r2_scores))
print(rs[np.argmax(np.array(r2_scores))]) #It returns the index of max value
print("------------------------------------------------------------")
print(lr.coef_)
print(lr.intercept_)
# Out:
# 0.5912016562257001
# 0
# ------------------------------------------------------------
# [3.49401689]
# 0.7841366845104432
