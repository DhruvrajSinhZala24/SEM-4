# %%
import pandas as pd
df=pd.read_csv("supermarket_sales.csv")
df
# Out:
#      Unnamed: 0   invoice id branch       city customer type  gender  \
# 0             0  750-67-8428      A     Yangon        Member  Female
# 1             1  226-31-3081      C  Naypyitaw        Normal  Female
# 2             2  631-41-3108      A     Yangon        Normal    Male
# 3             3  123-19-1176      A     Yangon        Member    Male
# 4             4  373-73-7910      A     Yangon        Normal    Male
# ..          ...          ...    ...        ...           ...     ...
# 995         995  233-67-5758      C  Naypyitaw        Normal    Male
# 996         996  303-96-2227      B   Mandalay        Normal  Female
# 997         997  727-02-1313      A     Yangon        Member    Male
# 998         998  347-56-2442      A     Yangon        Normal    Male
# 999         999  849-09-3807      A     Yangon        Member  Female
#
#                product line  unit price  quantity   tax 5%      total  \
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0   invoice id branch       city customer type  gender  \
# 0           0  750-67-8428      A     Yangon        Member  Female
# 1           1  226-31-3081      C  Naypyitaw        Normal  Female
# 2           2  631-41-3108      A     Yangon        Normal    Male
# 3           3  123-19-1176      A     Yangon        Member    Male
# 4           4  373-73-7910      A     Yangon        Normal    Male
# 5           5  699-14-3026      C  Naypyitaw        Normal    Male
# 6           6  355-53-5943      A     Yangon        Member  Female
# 7           7  315-22-5665      C  Naypyitaw        Normal  Female
# 8           8  665-32-9167      A     Yangon        Member  Female
# 9           9  692-92-5582      B   Mandalay        Member  Female
#
#              product line  unit price  quantity   tax 5%     total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1000 non-null   int64
#  1   invoice id               1000 non-null   object
#  2   branch                   1000 non-null   object
#  3   city                     1000 non-null   object
#  4   customer type            996 non-null    object
#  5   gender                   995 non-null    object
#  6   product line             1000 non-null   object
#  7   unit price               1000 non-null   float64
#  8   quantity                 1000 non-null   int64
#  9   tax 5%                   1000 non-null   float64
#  10  total                    1000 non-null   float64
#  11  date                     1000 non-null   object
#  12  time                     1000 non-null   object
#  13  payment                  1000 non-null   object
# ...

# %%
df['gross income'].fillna(df['gross income'].mean(),inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1000 non-null   int64
#  1   invoice id               1000 non-null   object
#  2   branch                   1000 non-null   object
#  3   city                     1000 non-null   object
#  4   customer type            996 non-null    object
#  5   gender                   995 non-null    object
#  6   product line             1000 non-null   object
#  7   unit price               1000 non-null   float64
#  8   quantity                 1000 non-null   int64
#  9   tax 5%                   1000 non-null   float64
#  10  total                    1000 non-null   float64
#  11  date                     1000 non-null   object
#  12  time                     1000 non-null   object
#  13  payment                  1000 non-null   object
# ...

# %%
df['customer type'].fillna(df['customer type'].mode()[0],inplace=True)
df['gender'].fillna(df['gender'].mode()[0],inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1000 non-null   int64
#  1   invoice id               1000 non-null   object
#  2   branch                   1000 non-null   object
#  3   city                     1000 non-null   object
#  4   customer type            1000 non-null   object
#  5   gender                   1000 non-null   object
#  6   product line             1000 non-null   object
#  7   unit price               1000 non-null   float64
#  8   quantity                 1000 non-null   int64
#  9   tax 5%                   1000 non-null   float64
#  10  total                    1000 non-null   float64
#  11  date                     1000 non-null   object
#  12  time                     1000 non-null   object
#  13  payment                  1000 non-null   object
# ...

# %%
x=df.loc[df["branch"]=='A','total'].sum()
y=df.loc[df["branch"]=='B','total'].sum()
z=df.loc[df["branch"]=='C','total'].sum()
print(f"Revenue of branch a:- {x}")
print(f"Revenue of branch b:- {y}")
print(f"Revenue of branch c:- {z}")
# Out:
# Revenue of branch a:- 106200.3705
# Revenue of branch b:- 106197.67199999999
# Revenue of branch c:- 110568.7065

# %%
# df['product line'].value_counts()
d={}
for i in df['product line']:
    d[i]=d.get(i,0)+1
d=sorted(d.items(), key=lambda x:x[1], reverse=True)[:5]
print(d)
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: product line, dtype: int64

# %%
rating_a=df.loc[df['branch']=='A','rating'].mean()
rating_b=df.loc[df['branch']=='B','rating'].mean()
rating_c=df.loc[df['branch']=='C','rating'].mean()
print(f"Rating of branch A:- {rating_a}")
print(f"Rating of branch B:- {rating_b}")
print(f"Rating of branch C:- {rating_c}")
# Out:
# Rating of branch A:- 7.026535914870589
# Rating of branch B:- 6.822735363566264
# Rating of branch C:- 7.072865853658538

# %%
d={}
for i in df['payment']:
    d[i]=d.get(i,0)+1
d=sorted(d.items(), key=lambda x:x[1], reverse=True)
print(d[0])
# Out:
# ('Ewallet', 345)

# %%
total=df.loc[df['customer type']=='Member','customer type'].count()
print(total)
# Out:
# 502

# %%
pd.crosstab(df['customer type'],df['payment'])
# Out:
# payment        Cash  Credit card  Ewallet
# customer type
# Member          169          172      161
# Normal          175          139      184

# %%
week=sum(df.loc[(df['day_of_week']=='Saturday')| (df['day_of_week']=='Sunday'),'total'])
print(week)
# Out:
# 100578.70199999999

# %%
non_week=sum(df.loc[(df['day_of_week']!='Saturday')&(df['day_of_week']!='Sunday'),'total'])
print(non_week)
# Out:
# 222388.04699999993

# %%
import re
'''wap using regx to check email address jhonedoe123@gmail.com'''
s=input("Enter The Mail:- ")
x=re.search(r"\w+[@]\w+([.][a-z]{2,3}){1,2}",s)
if x:
    print("Valid Email")
else:
    print("Invalid Email")
# Out:
# Enter The Mail:- uyasdfyh1@gmail.co.in
# Valid Email
