# %%
import pandas as pd
L=[1,4,6,8.34]
# L=[1,4,6,8.34,None] for None the data type will be float64 and the output will be in float eg: 1.00 4.00 ... NaN
df=pd.Series(L)
print(df)
#Higher datatye will be the dtype & string dtype will be object
# Out:
# 0    1.00
# 1    4.00
# 2    6.00
# 3    8.34
# dtype: float64

# %%
import pandas as pd
L=[50,60,70,80]
s=["fsd 2","coa","toc","fcsp 2"]
df=pd.Series(L,index=s)
print(df)
d={"a":1,"b":2,"c":3}
df=pd.Series(d,name="Series")
print(df)
# Out:
# fsd 2     50
# coa       60
# toc       70
# fcsp 2    80
# dtype: int64
# a    1
# b    2
# c    3
# Name: Series, dtype: int64

# %%
import pandas as pd
d={"a":1,"b":2,"c":3}
df=pd.Series(d,name="series",index=["x",'y','z'])
print(df)
# Out:
# x   NaN
# y   NaN
# z   NaN
# Name: series, dtype: float64

# %%
import pandas as pd
import numpy as np
# L=np.array([1,2,3])
L=[1,2,3]
df=pd.Series(L,copy=False)# copy=False is a default value for list copy = false or true dosen't matter
df[1]=50
print(L) # here if we keep copy = False then it will change the value of first index for numpy only [1 50 3],if copy=True
#then [1 2 3]
print(df)
# Out:
# [1, 2, 3]
# 0     1
# 1    50
# 2     3
# dtype: int64

# %%
#DataFrame

# %%
import pandas as pd
data=[[100,80,15],[60,70,30],[40,100,30],[80,50,20]]
df=pd.DataFrame(data,columns=['A','B','C']) #if we do not give coumns then the column index will be 0 1 2
print(df)
# Out:
#      A    B   C
# 0  100   80  15
# 1   60   70  30
# 2   40  100  30
# 3   80   50  20

# %%
import pandas as pd
data={'name':['a','b','c','d'],'id':[1,2,3,4],'marks':[80,70,60,50],'package':[10,7,3,5]}
df=pd.DataFrame(data)
df.set_index('id',inplace=True) #inplace=True is important
df
# Out:
#    name  marks  package
# id
# 1     a     80       10
# 2     b     70        7
# 3     c     60        3
# 4     d     50        5

# %%
import pandas as pd
df=pd.read_csv("Book1.csv")
print(type(df))
df
df1=df['cgpa']
print(type(df1))
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# 0      6.89
# 1      5.12
# 2      7.82
# 3      7.42
# 4      6.94
#        ...
# 195    6.93
# 196    5.89
# 197    7.21
# 198    7.63
# 199    6.22
# Name: cgpa, Length: 200, dtype: float64

# %%
import pandas as pd
df=pd.read_csv("movie.csv")
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.T
# Out:
#                                                                         0     \
# color                                                                  Color
# director_name                                                  James Cameron
# num_critic_for_reviews                                                   723
# duration                                                                 178
# director_facebook_likes                                                    0
# actor_3_facebook_likes                                                   855
# actor_2_name                                                Joel David Moore
# actor_1_facebook_likes                                                  1000
# gross                                                            7.60506e+08
# genres                                       Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                     CCH Pounder
# ...

# %%
df.shape
# Out:
# (4916, 28)

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=4916, step=1), Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')]

# %%
print(df.columns)
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
import pandas as pd
df1=pd.DataFrame({"A":[]})
df1
# Out:
# Empty DataFrame
# Columns: [A]
# Index: []

# %%
df1.empty
# Out:
# True

# %%
df2=pd.DataFrame({"A":[np.nan]})
df2
# Out:
#     A
# 0 NaN

# %%
df2.empty
# Out:
# False

# %%
d=[{'a':1,'b':2,'c':3,'d':4},{'a':10,'b':20,'c':30,'d':40},{'a':100,'b':200,'c':300,'d':400}]
df=pd.DataFrame(d)
df
# Out:
#      a    b    c    d
# 0    1    2    3    4
# 1   10   20   30   40
# 2  100  200  300  400

# %%
print(df.iloc[0])
print("``````````````````````````````````````````````````````````````````````")
print(df.iloc[[0]])
print("``````````````````````````````````````````````````````````````````````")
print(df.iloc[:2])
print("``````````````````````````````````````````````````````````````````````")
print(df.iloc[0:2,1:3])
print("``````````````````````````````````````````````````````````````````````")
print(df.iloc[[True,False,True]]) #oth and 2nd row will be there and 1st will be not there as t f t or df.iloc[[1,2]]
print("``````````````````````````````````````````````````````````````````````")
print(df.iloc[lambda x:x.index%2==0])
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: 0, dtype: int64
# ``````````````````````````````````````````````````````````````````````
#    a  b  c  d
# 0  1  2  3  4
# ``````````````````````````````````````````````````````````````````````
#     a   b   c   d
# 0   1   2   3   4
# 1  10  20  30  40
# ``````````````````````````````````````````````````````````````````````
#     b   c
# 0   2   3
# 1  20  30
# ``````````````````````````````````````````````````````````````````````
#      a    b    c    d
# 0    1    2    3    4
# 2  100  200  300  400
# ``````````````````````````````````````````````````````````````````````
#      a    b    c    d
# 0    1    2    3    4
# 2  100  200  300  400

# %%
df=pd.DataFrame([[1,2],[4,8],[9,11]],index=['A','B','C'],columns=['x','y'])
df
# Out:
#    x   y
# A  1   2
# B  4   8
# C  9  11

# %%
print(df.loc['C'])
print("``````````````````````````````````````````````````````````````````````")
print(df.loc['A':'C'])
print("``````````````````````````````````````````````````````````````````````")
print(df.loc[:,'x'])
print("``````````````````````````````````````````````````````````````````````")
print(df.loc[:,:'y'])
print("``````````````````````````````````````````````````````````````````````")
print(df.loc[:,'x':])
print("``````````````````````````````````````````````````````````````````````")
print(df.loc[['A','C'],'x'])
print("``````````````````````````````````````````````````````````````````````")
print(df.loc['A','x'])
print("``````````````````````````````````````````````````````````````````````")
print(df.loc[df['x']>3])
print("``````````````````````````````````````````````````````````````````````")
print(df>3)
print("``````````````````````````````````````````````````````````````````````")
print(df.loc[df['x']>3,'y'])
print("``````````````````````````````````````````````````````````````````````")
print(df.loc[lambda df:df['y']==8])
print("``````````````````````````````````````````````````````````````````````")
print(df.loc[(df['x']>3)&(df['y']<10)])
print("``````````````````````````````````````````````````````````````````````")
df.loc[['B','C'],'y']=50
print(df)
print("``````````````````````````````````````````````````````````````````````")
df.loc['A']=10
print(df)
print("``````````````````````````````````````````````````````````````````````")
df.loc[df['y']>35]=0
print(df)
# Out:
# x    0
# y    0
# Name: C, dtype: int64
# ``````````````````````````````````````````````````````````````````````
#     x   y
# A  10  10
# B   0   0
# C   0   0
# ``````````````````````````````````````````````````````````````````````
# A    10
# B     0
# C     0
# Name: x, dtype: int64
# ``````````````````````````````````````````````````````````````````````
#     x   y
# A  10  10
# B   0   0
# C   0   0
# ``````````````````````````````````````````````````````````````````````
#     x   y
# A  10  10
# B   0   0
# C   0   0
# ``````````````````````````````````````````````````````````````````````
# A    10
# C     0
# Name: x, dtype: int64
# ``````````````````````````````````````````````````````````````````````
# 10
# ``````````````````````````````````````````````````````````````````````
#     x   y
# A  10  10
# ``````````````````````````````````````````````````````````````````````
#        x      y
# A   True   True
# B  False  False
# C  False  False
# ...

# %%
tupels=[('cobra','mark1'),('cobra','mark2'),('sidewinder','mark1'),('sidewinder','mark2'),('viper','mark1'),('viper','mark2')]
index=pd.MultiIndex.from_tuples(tupels)
values=[[12,2],[0,9],[10,20],[1,4],[7,1],[16,36]]
df=pd.DataFrame(values,columns=["maxspeed","shield"],index=index)
print(df)
# Out:
#                   maxspeed  shield
# cobra      mark1        12       2
#            mark2         0       9
# sidewinder mark1        10      20
#            mark2         1       4
# viper      mark1         7       1
#            mark2        16      36

# %%
movie=pd.read_csv("movie.csv")
print(movie)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
print(movie.loc[:,'director_name'].values)
# Out:
# ['James Cameron' 'Gore Verbinski' 'Sam Mendes' ... 'Benjamin Roberds'
#  'Daniel Hsia' 'Jon Gunn']

# %%
#9 marksimportant functions
movie.head() #gives first 5 rows andif we pass any number in the method then it will return that many rows from top
# eg:- movie.head(9)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie.info()#gives all the info of the rows having non null coluns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
movie.tail() #gives last 5 rows
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# ...

# %%
movie.describe() # only gives columns having numeric values
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
movie.describe(include="all")
# Out:
#         color     director_name  num_critic_for_reviews     duration  \
# count    4897              4814             4867.000000  4901.000000
# unique      2              2397                     NaN          NaN
# top     Color  Steven Spielberg                     NaN          NaN
# freq     4693                26                     NaN          NaN
# mean      NaN               NaN              137.988905   107.090798
# std       NaN               NaN              120.239379    25.286015
# min       NaN               NaN                1.000000     7.000000
# 25%       NaN               NaN               49.000000    93.000000
# 50%       NaN               NaN              108.000000   103.000000
# 75%       NaN               NaN              191.000000   118.000000
# max       NaN               NaN              813.000000   511.000000
#
#         director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# ...

# %%
movie.describe(percentiles=[0.20,0.40,0.60])
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 20%                 39.000000    91.000000                 3.000000
# 40%                 82.000000    99.000000                25.000000
# 50%                108.000000   103.000000                48.000000
# 60%                137.000000   108.000000                83.800000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# ...

# %%
movie.isna() # or isnull() it gives true where fieldis null and false for not null
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     False          False                   False     False
# 1     False          False                   False     False
# 2     False          False                   False     False
# 3     False          False                   False     False
# 4      True          False                    True      True
# ...     ...            ...                     ...       ...
# 4911  False          False                   False     False
# 4912  False           True                   False     False
# 4913  False          False                   False     False
# 4914  False          False                   False     False
# 4915  False          False                   False     False
#
#       director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                       False                   False         False
# 1                       False                   False         False
# ...

# %%
movie.isna().sum() #gives count ofthe null values of columns
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
movie.isna().any().sum() # it gives the count of total columns having null values
# Out:
# 21

# %%
movie.dropna() #removes the rows having null values
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 4899  Color    Olivier Assayas                    81.0     110.0
# 4900  Color       Jafar Panahi                    64.0      90.0
# 4906  Color      Shane Carruth                   143.0      77.0
# 4908  Color   Robert Rodriguez                    56.0      81.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
movie.dropna(axis=1) # axis=0 for rows and 1 for column
# Out:
#                                genres  \
# 0     Action|Adventure|Fantasy|Sci-Fi
# 1            Action|Adventure|Fantasy
# 2           Action|Adventure|Thriller
# 3                     Action|Thriller
# 4                         Documentary
# ...                               ...
# 4911                     Comedy|Drama
# 4912     Crime|Drama|Mystery|Thriller
# 4913            Drama|Horror|Thriller
# 4914             Comedy|Drama|Romance
# 4915                      Documentary
#
#                                      movie_title  num_voted_users  \
# 0                                         Avatar           886204
# 1       Pirates of the Caribbean: At World's End           471220
# 2                                        Spectre           275868
# 3                          The Dark Knight Rises          1144337
# 4     Star Wars: Episode VII - The Force Awakens                8
# ...                                          ...              ...
# ...

# %%
movie.dropna(how="all") # id therow has all the null values thenit will be removed
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'A':[1,2,np.nan,4,np.nan],'B':[np.nan,6,7,np.nan,np.nan],'C':[10,11,np.nan,np.nan,14]})
df
df.dropna(thresh=2) # the values passed in thresh checks if it has 2 or more not null value then it will be not removed 
# for understanding the first row has 2 not null values so it will not be droped and 3rd row has 1 not null value then it
# will be droped
# Out:
#      A    B     C
# 0  1.0  NaN  10.0
# 1  2.0  6.0  11.0

# %%
df.dropna(subset=['B','C'])
# Out:
#      A    B     C
# 1  2.0  6.0  11.0

# %%
df.drop_duplicates(subset=['A','B']) #drop the duplicate rows if value from both a nd b are common otherwise it will not
# Out:
#      A    B     C
# 0  1.0  NaN  10.0
# 1  2.0  6.0  11.0
# 2  NaN  7.0   NaN
# 3  4.0  NaN   NaN
# 4  NaN  NaN  14.0

# %%
df.drop('B',axis=1)
# Out:
#      A     C
# 0  1.0  10.0
# 1  2.0  11.0
# 2  NaN   NaN
# 3  4.0   NaN
# 4  NaN  14.0

# %%
df.drop(1,inplace=True) #it has deleted the 1 index row so if we now again to try to delete that index then it will
# give error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-c8cc869aee87> in <module>
# ----> 1 df.drop(1,inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
df
# Out:
#      A    B     C
# 0  1.0  NaN  10.0
# 2  NaN  7.0   NaN
# 3  4.0  NaN   NaN
# 4  NaN  NaN  14.0
